# %% [markdown]
# # Explore the two datasources - Traffic violations
#
# For the same topic, two different versions of the same dataset were identified, which were both published on openML.
#
# The first is unprocessed and can be found [here](https://api.openml.org/d/42132). The second one is a preprocessed and subsampled version that can be downloaded [here](https://www.openml.org/search?type=data&status=active&sort=runs&order=desc&id=42345).

# %%
from pathlib import Path

import pandas as pd
from scipy.io.arff import loadarff

# %%
FULL_DATA_PATH = Path("..") / ".." / "data" / "dataset.csv"
DATA_PATH = Path("..") / ".." / "data" / "file65ef3a759daf.arff"

# %% [markdown]
# ## Preprocessed dataset

# %%
data, meta = loadarff(DATA_PATH)
data = pd.DataFrame(data)

# %%
print("Dimensions of the dataset:", data.shape)
# Out:
# Dimensions of the dataset: (70340, 21)

# %%
data.columns
# Out:
# Index(['Description', 'Belts', 'Personal.Injury', 'Property.Damage',
#        'Commercial.License', 'Commercial.Vehicle', 'State', 'VehicleType',
#        'Year', 'Make', 'Model', 'Color', 'Charge', 'Contributed.To.Accident',
#        'Race', 'Gender', 'Driver.City', 'Driver.State', 'DL.State',
#        'Arrest.Type', 'Violation.Type'],
#       dtype='object')

# %%
data.head()
# Out:
#                                          Description  Belts Personal.Injury  \
# 0  b'DISPLAYING EXPIRED REGISTRATION PLATE ISSUED...  b'No'           b'No'
# 1  b'DRIVER FAIL TO STOP AT RED TRAFFIC SIGNAL BE...  b'No'           b'No'
# 2   b'DRIVING UNDER THE INFLUENCE OF ALCOHOL PER SE'  b'No'           b'No'
# 3  b'PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR P...  b'No'           b'No'
# 4  b'DISPLAYING EXPIRED REGISTRATION PLATE ISSUED...  b'No'           b'No'
#
#   Property.Damage Commercial.License Commercial.Vehicle  State  \
# 0           b'No'              b'No'              b'No'  b'NC'
# 1           b'No'              b'No'              b'No'  b'MD'
# 2           b'No'              b'No'              b'No'  b'MD'
# 3           b'No'              b'No'              b'No'  b'MD'
# 4           b'No'             b'Yes'              b'No'  b'MD'
#
#           VehicleType    Year        Make  ...      Color      Charge  \
# 0  b'02 - Automobile'  2013.0  b'HYUNDAI'  ...    b'GRAY'   b'13411f'
# 1  b'02 - Automobile'  2015.0     b'FORD'  ...  b'SILVER'  b'21202i1'
# 2  b'02 - Automobile'  2000.0   b'TOYOTA'  ...   b'BLACK'  b'21902a2'
# 3  b'02 - Automobile'  2012.0     b'HOND'  ...   b'BLACK'   b'16303c'
# 4  b'02 - Automobile'  2010.0     b'FORD'  ...   b'BLACK'   b'13411f'
#
#   Contributed.To.Accident      Race Gender       Driver.City Driver.State  \
# 0                   b'No'  b'WHITE'   b'F'      b'ASHEVILLE'        b'NC'
# 1                   b'No'  b'OTHER'   b'M'  b'SILVER SPRING'        b'MD'
# 2                   b'No'  b'BLACK'   b'M'  b'SILVER SPRING'        b'MD'
# 3                   b'No'  b'BLACK'   b'M'       b'COLUMBIA'        b'MD'
# 4                   b'No'  b'WHITE'   b'M'     b'MOUNT AIRY'        b'MD'
#
#   DL.State             Arrest.Type Violation.Type
# 0    b'NC'    b'A - Marked Patrol'    b'Citation'
# 1    b'MD'    b'A - Marked Patrol'    b'Citation'
# 2    b'MD'  b'B - Unmarked Patrol'    b'Citation'
# 3    b'MD'    b'A - Marked Patrol'    b'Citation'
# 4    b'MD'    b'A - Marked Patrol'    b'Citation'
#
# [5 rows x 21 columns]

# %%
# remove b string from data
str_df = data.select_dtypes([object])
str_df = str_df.stack().str.decode("utf-8").unstack()
data = pd.concat([str_df, data.select_dtypes(exclude=[object])], axis=1)

# %%
data.head()
# Out:
#                                          Description Belts Personal.Injury  \
# 0  DISPLAYING EXPIRED REGISTRATION PLATE ISSUED B...    No              No
# 1  DRIVER FAIL TO STOP AT RED TRAFFIC SIGNAL BEFO...    No              No
# 2      DRIVING UNDER THE INFLUENCE OF ALCOHOL PER SE    No              No
# 3  PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUB...    No              No
# 4  DISPLAYING EXPIRED REGISTRATION PLATE ISSUED B...    No              No
#
#   Property.Damage Commercial.License Commercial.Vehicle State  \
# 0              No                 No                 No    NC
# 1              No                 No                 No    MD
# 2              No                 No                 No    MD
# 3              No                 No                 No    MD
# 4              No                Yes                 No    MD
#
#        VehicleType     Make      Model  ...   Charge Contributed.To.Accident  \
# 0  02 - Automobile  HYUNDAI     SONATA  ...   13411f                      No
# 1  02 - Automobile     FORD     FUSION  ...  21202i1                      No
# 2  02 - Automobile   TOYOTA      CAMRY  ...  21902a2                      No
# 3  02 - Automobile     HOND  CROSSTOUR  ...   16303c                      No
# 4  02 - Automobile     FORD       F250  ...   13411f                      No
#
#     Race Gender    Driver.City Driver.State DL.State          Arrest.Type  \
# 0  WHITE      F      ASHEVILLE           NC       NC    A - Marked Patrol
# 1  OTHER      M  SILVER SPRING           MD       MD    A - Marked Patrol
# 2  BLACK      M  SILVER SPRING           MD       MD  B - Unmarked Patrol
# 3  BLACK      M       COLUMBIA           MD       MD    A - Marked Patrol
# 4  WHITE      M     MOUNT AIRY           MD       MD    A - Marked Patrol
#
#   Violation.Type    Year
# 0       Citation  2013.0
# 1       Citation  2015.0
# 2       Citation  2000.0
# 3       Citation  2012.0
# 4       Citation  2010.0
#
# [5 rows x 21 columns]

# %% [markdown]
# Check distribution of target variable and obvious protected attributes

# %%
data["Violation.Type"].value_counts()
# Out:
# Violation.Type
# Warning     34382
# Citation    32452
# SERO         3506
# Name: count, dtype: int64

# %%
data["Race"].value_counts()
# Out:
# Race
# WHITE              24973
# BLACK              22249
# HISPANIC           15035
# ASIAN               4140
# OTHER               3784
# NATIVE AMERICAN      159
# Name: count, dtype: int64

# %%
data["Gender"].value_counts()
# Out:
# Gender
# M    47163
# F    23087
# U       90
# Name: count, dtype: int64

# %% [markdown]
# ## Full dataset

# %% [markdown]
# WARNING: the following code does not load the data in a fully correct manner. It was nonetheless used to get a first impression of the dataset and the cleanliness.

# %%
df = pd.read_csv(FULL_DATA_PATH, quotechar="'", on_bad_lines="skip")
# Out:
# /var/folders/y_/2nw1qxt94ydbkmv5qzg8p4080000gn/T/ipykernel_20495/577714472.py:1: DtypeWarning: Columns (8,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(FULL_DATA_PATH, quotechar="'", on_bad_lines="skip")

# %%
df.shape
# Out:
# (1578095, 43)

# %%
df.columns = df.columns.str.replace('"', "")

# %%
df.columns
# Out:
# Index(['seqid', 'date_of_stop', 'time_of_stop', 'agency', 'subagency',
#        'description', 'location', 'latitude', 'longitude', 'accident', 'belts',
#        'personal_injury', 'property_damage', 'fatal', 'commercial_license',
#        'hazmat', 'commercial_vehicle', 'alcohol', 'work_zone',
#        'search_conducted', 'search_disposition', 'search_outcome',
#        'search_reason', 'search_reason_for_stop', 'search_type',
#        'search_arrest_reason', 'state', 'vehicletype', 'year', 'make', 'model',
#        'color', 'violation_type', 'charge', 'article',
#        'contributed_to_accident', 'race', 'gender', 'driver_city',
#        'driver_state', 'dl_state', 'arrest_type', 'geolocation'],
#       dtype='object')

# %%
df.head()
# Out:
#                                   seqid date_of_stop time_of_stop agency  \
# 0  fdcc1a6b-4854-4cde-bb60-248f478fa5b6   09/11/2019     09:56:00    MCP
# 1  842dad60-5edf-47a8-9e94-c7e6da729498   09/11/2019     09:42:00    MCP
# 2  4db837cc-f2fa-4a5b-9ac8-37698492b5f9   09/11/2019     09:36:00    MCP
# 3  79761295-50f6-4336-8b48-fdf55e87a326   09/11/2019     09:33:00    MCP
# 4  f9a7a508-386c-466e-95b2-dbf26d7d59fe   09/11/2019     09:30:00    MCP
#
#                  subagency                                        description  \
# 0   2nd District, Bethesda                                    STOP LIGHTS (*)
# 1  1st District, Rockville  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 2  1st District, Rockville  FAILURE VEH. TO YIELD INTERSECTION RIGHT-OF-WA...
# 3   2nd District, Bethesda  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 4    4th District, Wheaton       MOTOR VEH. W/O REQUIRED STOP LAMPS EQUIPMENT
#
#                            location   latitude  longitude accident  ...  \
# 0               27 @ SWEEPSTAKES RD  39.259627  -77.22376       No  ...
# 1         FREDERICK RD / REDLAND RD  39.112860 -77.162435       No  ...
# 2          S/B GEORGIA AVE AT MD200  39.117080 -77.068113       No  ...
# 3  OLD GEORGETOWN RD AT MCKINLEY ST  38.991630 -77.105873       No  ...
# 4       CONNECTICUT AVE / WELLER RD  39.064560 -77.073673       No  ...
#
#        charge                 article contributed_to_accident      race  \
# 0         64*                       ?                   False  HISPANIC
# 1  21-201(a1)  Transportation Article                   False     BLACK
# 2      21-401  Transportation Article                   False     WHITE
# 3  21-201(a1)  Transportation Article                   False     BLACK
# 4   22-206(a)  Transportation Article                   False     BLACK
#
#   gender    driver_city driver_state dl_state          arrest_type  \
# 0      F       DAMASCUS           MD       MD  B - Unmarked Patrol
# 1      M   TEMPLE HILLS           MD       MD    A - Marked Patrol
# 2      M          OLNEY           MD       MD    A - Marked Patrol
# 3      F   GAITHERSBURG           MD       MD    A - Marked Patrol
# 4      F  SILVER SPRING           MD       MD    A - Marked Patrol
#
#                      geolocation
# 0  (39.2596266666667, -77.22376)
# 1         (39.11286, -77.162435)
# 2  (39.11708, -77.0681133333333)
# 3  (38.99163, -77.1058733333333)
# 4  (39.06456, -77.0736733333333)
#
# [5 rows x 43 columns]
